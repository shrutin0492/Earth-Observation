# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutin567/Earth-Observation/blob/main/add_colour_bars_to_maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geemap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 57.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 75.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.2 MB/s eta 0:00:00
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11122 sha256=76c132c029c59955b824e410304581709c3b687394f13e0b2a7a4c15456eb610
# ...

# %%
ee.Authenticate()
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=x9EvCb9-UpLXBGHXy297D7uVgfrus6GBiI98VQn9Hzk&tc=kAXiny10d5LZUrO2zrWfI6sSRII28Tatplucl-7P1sw&cc=b-Xs5GubNNy9olD6p7wVaoXHOXpYe2AglkkyqB6A3sU
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1Adeu5BUNHzWP5O8EB1giJffUXSvPLPF3hfXvR7mSQQlMtZKO898LWxeugbI
#
# Successfully saved authorization token.

# %%
# !pip install geemap
# !pip install earthengine-api

# %%
#import libraries
import ee
import geemap

# %%
# Load countries data
countries = ee.FeatureCollection("USDOS/LSIB_SIMPLE/2017")
roi = countries.filter(ee.Filter.eq("country_na", "United States"))
dem = ee.Image('USGS/SRTMGL1_003').clip(roi.geometry())  # Use roi.geometry() to get the geometry
vis_params = {
    'min': 0,
    'max': 4000,
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5'],
}

Map.addLayer(dem, vis_params, 'SRTM DEM')
Map.centerObject(roi, 4)


colors=vis_params['palette']
vmin=vis_params['min']
vmax=vis_params['max']
Map.add_colorbar(vis_params,label="Elevation (m)",layer_name="SRTM DEM") #horizontal orientation
Map.centerObject(roi,4)
Map
# Out:
# Map(bottom=538.0, center=[39.76850680995396, -99.05366228420321], controls=(WidgetControl(options=['position',…

# %%
#vertical orientation
Map.add_colorbar(vis_params, label="DEM (m)",layer_name="SRTM DEM",orientation="vertical")
#add transparency to legend
Map.add_colorbar(
    vis_params,
    label="Elevation(m)",
    layer_name="SRTM DEM",
    orientation="vertical",
    transparent_bg=True,
)
Map
# Out:
# Map(bottom=654.0, center=[48.45835136104332, 42.00753766831513], controls=(WidgetControl(options=['position', …

# %%
#add classification to legend
Map.add_colorbar(
    vis_params,
    label="Elevation (m)",
    layer_name="SRTM DEM",
    orientation="vertical",
    transparent_bg=True,
    discrete=True,
)
Map
# Out:
# Map(bottom=654.000002237956, center=[48.45835136104332, 42.00753766831513], controls=(WidgetControl(options=['…
